# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
with open("json_file.txt") as f:
    lines = f.read().splitlines()

# %%
df_inter = pd.DataFrame(lines)
df_inter
# Out:
#                                                    0
# 0   {"name": "John", "wins": [["straight", "7â™£"]]}
# 1  {"name": "Jacob", "wins": [["two pair", "4â™ "...
# 2                     {"name": "Martin", "wins": []}
# 3  {"name": "Larry", "wins": [["three of a kind",...

# %%
df_inter.columns = ['json_element']

# %%
df_inter
# Out:
#                                         json_element
# 0   {"name": "John", "wins": [["straight", "7â™£"]]}
# 1  {"name": "Jacob", "wins": [["two pair", "4â™ "...
# 2                     {"name": "Martin", "wins": []}
# 3  {"name": "Larry", "wins": [["three of a kind",...

# %%
import json
df_inter['json_element'].apply(json.loads)
# Out:
# 0     {'name': 'John', 'wins': [['straight', '7â™£']]}
# 1    {'name': 'Jacob', 'wins': [['two pair', '4â™ '...
# 2                       {'name': 'Martin', 'wins': []}
# 3    {'name': 'Larry', 'wins': [['three of a kind',...
# Name: json_element, dtype: object

# %%
df_final = pd.json_normalize(df_inter['json_element'].apply(json.loads))

# %%
df_final
# Out:
#      name                                  wins
# 0    John                    [[straight, 7â™£]]
# 1   Jacob  [[two pair, 4â™ ], [two pair, 9â™ ]]
# 2  Martin                                    []
# 3   Larry             [[three of a kind, 5â™£]]

# %%
bond1=pd.DataFrame()

# %%
bond.sort_values(["Year","Film"],ascending=[False,True])
# Out:
#                                Film  Year           Actor            Director  \
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 0                            Dr. No  1962    Sean Connery       Terence Young
#
#     Box Office  Budget  Bond Actor Salary
# 25       726.7   206.3                NaN
# 24       943.5   170.2               14.5
# 23       514.2   181.4                8.1
# 22       581.5   145.3                3.3
# 21       465.4   154.2               17.9
# 20       439.5   158.3               13.5
# 19       463.2   133.9               10.0
# 18       518.5    76.9                5.1
# 17       250.9    56.7                7.9
# 16       313.5    68.8                5.2
# 15       275.2    54.5                9.1
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 12       449.4    60.2                NaN
# 11       535.0    91.5                NaN
# 10       533.0    45.1                NaN
# 9        334.0    27.7                NaN
# 8        460.3    30.8                NaN
# 7        442.5    34.7                5.8
# 6        291.5    37.3                0.6
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 3        848.1    41.9                4.7
# 2        820.4    18.6                3.2
# 1        543.8    12.6                1.6
# 0        448.8     7.0                0.6

# %% [markdown]
# ## The `.set_index()` and `.reset_index()` Methods

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace = True)
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(drop = False, inplace = True)
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace = True)
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace = True)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
bond.set_index("Year", inplace = True)
bond.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %% [markdown]
# ## Retrieve Rows by Index Label with `.loc[]`

# %%
bond = pd.read_csv("jamesbond.csv", index_col = ["Film"])
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond1 = pd.read_csv("jamesbond.csv", index_col = ["Year","Film"])
bond1.sort_index(inplace = True)
bond1.head(100)
# Out:
#                                                Actor            Director  \
# Year Film
# 1962 Dr. No                             Sean Connery       Terence Young
# 1963 From Russia with Love              Sean Connery       Terence Young
# 1964 Goldfinger                         Sean Connery        Guy Hamilton
# 1965 Thunderball                        Sean Connery       Terence Young
# 1967 Casino Royale                       David Niven          Ken Hughes
#      You Only Live Twice                Sean Connery       Lewis Gilbert
# 1969 On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 1971 Diamonds Are Forever               Sean Connery        Guy Hamilton
# 1973 Live and Let Die                    Roger Moore        Guy Hamilton
# 1974 The Man with the Golden Gun         Roger Moore        Guy Hamilton
# 1977 The Spy Who Loved Me                Roger Moore       Lewis Gilbert
# 1979 Moonraker                           Roger Moore       Lewis Gilbert
# 1981 For Your Eyes Only                  Roger Moore           John Glen
# 1983 Never Say Never Again              Sean Connery      Irvin Kershner
#      Octopussy                           Roger Moore           John Glen
# 1985 A View to a Kill                    Roger Moore           John Glen
# 1987 The Living Daylights             Timothy Dalton           John Glen
# 1989 Licence to Kill                  Timothy Dalton           John Glen
# 1995 GoldenEye                        Pierce Brosnan     Martin Campbell
# 1997 Tomorrow Never Dies              Pierce Brosnan  Roger Spottiswoode
# 1999 The World Is Not Enough          Pierce Brosnan       Michael Apted
# 2002 Die Another Day                  Pierce Brosnan        Lee Tamahori
# 2006 Casino Royale                      Daniel Craig     Martin Campbell
# 2008 Quantum of Solace                  Daniel Craig        Marc Forster
# 2012 Skyfall                            Daniel Craig          Sam Mendes
# 2015 Spectre                            Daniel Craig          Sam Mendes
#
#                                       Box Office  Budget  Bond Actor Salary
# Year Film
# 1962 Dr. No                                448.8     7.0                0.6
# 1963 From Russia with Love                 543.8    12.6                1.6
# 1964 Goldfinger                            820.4    18.6                3.2
# 1965 Thunderball                           848.1    41.9                4.7
# 1967 Casino Royale                         315.0    85.0                NaN
#      You Only Live Twice                   514.2    59.9                4.4
# 1969 On Her Majesty's Secret Service       291.5    37.3                0.6
# 1971 Diamonds Are Forever                  442.5    34.7                5.8
# 1973 Live and Let Die                      460.3    30.8                NaN
# 1974 The Man with the Golden Gun           334.0    27.7                NaN
# 1977 The Spy Who Loved Me                  533.0    45.1                NaN
# 1979 Moonraker                             535.0    91.5                NaN
# 1981 For Your Eyes Only                    449.4    60.2                NaN
# 1983 Never Say Never Again                 380.0    86.0                NaN
#      Octopussy                             373.8    53.9                7.8
# 1985 A View to a Kill                      275.2    54.5                9.1
# 1987 The Living Daylights                  313.5    68.8                5.2
# 1989 Licence to Kill                       250.9    56.7                7.9
# 1995 GoldenEye                             518.5    76.9                5.1
# 1997 Tomorrow Never Dies                   463.2   133.9               10.0
# 1999 The World Is Not Enough               439.5   158.3               13.5
# 2002 Die Another Day                       465.4   154.2               17.9
# 2006 Casino Royale                         581.5   145.3                3.3
# 2008 Quantum of Solace                     514.2   181.4                8.1
# 2012 Skyfall                               943.5   170.2               14.5
# 2015 Spectre                               726.7   206.3                NaN

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
#bond.loc["Sacred Bond"]
bond.loc["Casino Royale"]
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond[20:30]
# Out:
#                        Film  Year           Actor         Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan    Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan     Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig  Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig     Marc Forster
# 24                  Skyfall  2012    Daniel Craig       Sam Mendes
# 25                  Spectre  2015    Daniel Craig       Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
bond.loc["Diamonds Are Forever" : "Moonraker"]
bond.loc[: "On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# Moonraker                        1979     Roger Moore    Lewis Gilbert
# Never Say Never Again            1983    Sean Connery   Irvin Kershner
# Octopussy                        1983     Roger Moore        John Glen
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.loc[["Octopussy", "Moonraker"]]
# Out:
#            Year        Actor       Director  Box Office  Budget  \
# Film
# Octopussy  1983  Roger Moore      John Glen       373.8    53.9
# Moonraker  1979  Roger Moore  Lewis Gilbert       535.0    91.5
#
#            Bond Actor Salary
# Film
# Octopussy                7.8
# Moonraker                NaN

# %%
bond.loc[["For Your Eyes Only","Octopussy"]]
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
"Gold Bond" in bond.index

# %% [markdown]
# ## Retrieve Row(s) by Index Position with `iloc`

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.iloc[15]

bond.iloc[[15, 20]]
bond.iloc[:4]
bond.iloc[4:8]
bond.iloc[20:]
# Out:
#                        Film  Year           Actor         Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan    Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan     Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig  Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig     Marc Forster
# 24                  Skyfall  2012    Daniel Craig       Sam Mendes
# 25                  Spectre  2015    Daniel Craig       Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
bond.iloc[[10,20,25]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 10     The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
# 25                  Spectre  2015    Daniel Craig     Sam Mendes       726.7
#
#     Budget  Bond Actor Salary
# 10    45.1                NaN
# 20   158.3               13.5
# 25   206.3                NaN

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)

# %%
bond.iloc[[5, 10, 15, 20]]

# %% [markdown]
# ## The Catch-All `.ix[]` Method

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["GoldenEye"]
bond.loc[["Moonraker", "Spectre"]]
bond.loc["A View to a Kill" : "The World Is Not Enough"]
# bond.ix["Sacred Bond"]
bond.loc[["Spectre"]]
# Out:
#          Year         Actor    Director  Box Office  Budget  Bond Actor Salary
# Film
# Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3                NaN

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Moonraker", ["Actor", "Budget", "Year"]]

bond.iloc[[14,15], [5, 3, 2]]
# Out:
#                                  Bond Actor Salary  Box Office       Director
# Film
# Octopussy                                      7.8       373.8      John Glen
# On Her Majesty's Secret Service                0.6       291.5  Peter R. Hunt

# %%
bond.ix[20, "Budget"]
bond.ix["The Man with the Golden Gun", :4]
bond.ix[5, 3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c16621cc8979> in <module>
# ----> 1 bond.ix[20, "Budget"]
#       2 bond.ix["The Man with the Golden Gun", :4]
#       3 bond.ix[5, 3]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %% [markdown]
# ## Set New Values for a Specific Cell or Row

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.reset_index(inplace=True)

# %%
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                  A View to a Kill  1985     Roger Moore           John Glen
# 1                     Casino Royale  2006    Daniel Craig     Martin Campbell
# 2                     Casino Royale  1967     David Niven          Ken Hughes
# 3              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 4                   Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 5                            Dr. No  1962    Sean Connery       Terence Young
# 6                For Your Eyes Only  1981     Roger Moore           John Glen
# 7             From Russia with Love  1963    Sean Connery       Terence Young
# 8                         GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 9                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 10                  Licence to Kill  1989  Timothy Dalton           John Glen
# 11                 Live and Let Die  1973     Roger Moore        Guy Hamilton
# 12                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15  On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 16                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 17                          Skyfall  2012    Daniel Craig          Sam Mendes
# 18                          Spectre  2015    Daniel Craig          Sam Mendes
# 19             The Living Daylights  1987  Timothy Dalton           John Glen
# 20      The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 21             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 22          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 23                      Thunderball  1965    Sean Connery       Terence Young
# 24              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 25              You Only Live Twice  1967    Sean Connery       Lewis Gilbert
#
#     Box Office  Budget  Bond Actor Salary
# 0        275.2    54.5                9.1
# 1        581.5   145.3                3.3
# 2        315.0    85.0                NaN
# 3        442.5    34.7                5.8
# 4        465.4   154.2               17.9
# 5        448.8     7.0                0.6
# 6        449.4    60.2                NaN
# 7        543.8    12.6                1.6
# 8        518.5    76.9                5.1
# 9        820.4    18.6                3.2
# 10       250.9    56.7                7.9
# 11       460.3    30.8                NaN
# 12       535.0    91.5                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       291.5    37.3                0.6
# 16       514.2   181.4                8.1
# 17       943.5   170.2               14.5
# 18       726.7   206.3                NaN
# 19       313.5    68.8                5.2
# 20       334.0    27.7                NaN
# 21       533.0    45.1                NaN
# 22       439.5   158.3               13.5
# 23       848.1    41.9                4.7
# 24       463.2   133.9               10.0
# 25       514.2    59.9                4.4

# %%
bond.loc[bond["Year"]==1967,"Year"]=1968

# %%
bond.loc["A View to a Kill","Director"]
# Out:
# 'Martin Campbell'

# %%
bond.loc["Octopussy","Year"]=1985

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore     Martin Campbell
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.loc["Dr. No"]
# Out:
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                         7.0
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.loc["Dr. No", "Actor"] = "Sir Sean Connery"

# %%
bond.loc["Dr. No", "Actor"]
# Out:
# 'Sir Sean Connery'

# %%
bond.loc["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = [448800000, 7000000, 600000]
bond.loc["Dr. No"]
# Out:
# Year                             1962
# Actor                Sir Sean Connery
# Director                Terence Young
# Box Office                448800000.0
# Budget                      7000000.0
# Bond Actor Salary            600000.0
# Name: Dr. No, dtype: object

# %%
bond.loc["Dr. No", "Budget"]
# Out:
# 7000000.0

# %% [markdown]
# ## Set Multiple Values in `DataFrame`

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond["Actor"] == "Sean Connery"

# %%
bond.loc[mask, "Actor"] = "Sir Sean Connery"

# %%
bond[bond["Actor"] == "Roger Moore"]

bond.loc[bond["Actor"] == "Roger Moore"]
# Out:
#                              Year        Actor       Director  Box Office  \
# Film
# A View to a Kill             1985  Roger Moore      John Glen       275.2
# For Your Eyes Only           1981  Roger Moore      John Glen       449.4
# Live and Let Die             1973  Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979  Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983  Roger Moore      John Glen       373.8
# The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977  Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond Actor Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# Live and Let Die               30.8                NaN
# Moonraker                      91.5                NaN
# Octopussy                      53.9                7.8
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN

# %% [markdown]
# ## Rename Index Labels or Columns in a `DataFrame`

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.rename(columns = {"Year" : "Release Date", "Box Office" : "Revenue"}, inplace = True)

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.rename(index = {"Dr. No" : "Doctor No", 
                     "GoldenEye" : "Golden Eye",
                    "The World Is Not Enough" : "Best Bond Movie Ever"}, inplace = True)

# %%
bond.loc["Best Bond Movie Ever"]
# Out:
# Release Date                   1999
# Actor                Pierce Brosnan
# Director              Michael Apted
# Revenue                       439.5
# Budget                        158.3
# Bond Actor Salary              13.5
# Name: Best Bond Movie Ever, dtype: object

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.columns = ["Year of Release", "Actor", "Director", "Gross", "Cost", "Salary"]

# %%
bond.head(3)
# Out:
#                   Year of Release         Actor         Director  Gross  \
# Film
# A View to a Kill             1985   Roger Moore        John Glen  275.2
# Casino Royale                2006  Daniel Craig  Martin Campbell  581.5
# Casino Royale                1967   David Niven       Ken Hughes  315.0
#
#                    Cost  Salary
# Film
# A View to a Kill   54.5     9.1
# Casino Royale     145.3     3.3
# Casino Royale      85.0     NaN

# %% [markdown]
# ## Delete Rows or Columns from a `DataFrame`

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# bond.drop("Casino Royale", inplace = True)
bond.drop(labels = ["Box Office", "Bond Actor Salary", "Actor"], axis = "columns").head(5)
# Out:
#                       Year         Director  Budget
# Film
# A View to a Kill      1985        John Glen    54.5
# Casino Royale         2006  Martin Campbell   145.3
# Casino Royale         1967       Ken Hughes    85.0
# Diamonds Are Forever  1971     Guy Hamilton    34.7
# Die Another Day       2002     Lee Tamahori   154.2

# %%
bond.head(5)
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
ret1 = bond.pop("Actor")

# %%
bond.head(5)
# Out:
#                       Year         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985        John Glen       275.2    54.5
# Casino Royale         2006  Martin Campbell       581.5   145.3
# Casino Royale         1967       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971     Guy Hamilton       442.5    34.7
# Die Another Day       2002     Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %%
ret1
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# The Living Daylights               Timothy Dalton
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# The World Is Not Enough            Pierce Brosnan
# Thunderball                          Sean Connery
# Tomorrow Never Dies                Pierce Brosnan
# You Only Live Twice                  Sean Connery
# Name: Actor, dtype: object

# %%
del bond["Actor"]

# %%
bond
# Out:
#                                           Actor            Director  \
# Film
# A View to a Kill                    Roger Moore           John Glen
# Casino Royale                      Daniel Craig     Martin Campbell
# Casino Royale                       David Niven          Ken Hughes
# Diamonds Are Forever               Sean Connery        Guy Hamilton
# Die Another Day                  Pierce Brosnan        Lee Tamahori
# Dr. No                             Sean Connery       Terence Young
# For Your Eyes Only                  Roger Moore           John Glen
# From Russia with Love              Sean Connery       Terence Young
# GoldenEye                        Pierce Brosnan     Martin Campbell
# Goldfinger                         Sean Connery        Guy Hamilton
# Licence to Kill                  Timothy Dalton           John Glen
# Live and Let Die                    Roger Moore        Guy Hamilton
# Moonraker                           Roger Moore       Lewis Gilbert
# Never Say Never Again              Sean Connery      Irvin Kershner
# Octopussy                           Roger Moore           John Glen
# On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# Quantum of Solace                  Daniel Craig        Marc Forster
# Skyfall                            Daniel Craig          Sam Mendes
# Spectre                            Daniel Craig          Sam Mendes
# The Living Daylights             Timothy Dalton           John Glen
# The Man with the Golden Gun         Roger Moore        Guy Hamilton
# The Spy Who Loved Me                Roger Moore       Lewis Gilbert
# The World Is Not Enough          Pierce Brosnan       Michael Apted
# Thunderball                        Sean Connery       Terence Young
# Tomorrow Never Dies              Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice                Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %% [markdown]
# ## Create Random Sample

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n = 5, axis = 0)
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# GoldenEye            1995  Pierce Brosnan     Martin Campbell       518.5
# Live and Let Die     1973     Roger Moore        Guy Hamilton       460.3
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
# A View to a Kill     1985     Roger Moore           John Glen       275.2
# Licence to Kill      1989  Timothy Dalton           John Glen       250.9
#
#                      Budget  Bond Actor Salary
# Film
# GoldenEye              76.9                5.1
# Live and Let Die       30.8                NaN
# Tomorrow Never Dies   133.9               10.0
# A View to a Kill       54.5                9.1
# Licence to Kill        56.7                7.9

# %% [markdown]
# ## The `.nsmallest()` and `.nlargest()` Methods

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sort_values("Box Office", ascending = False,axis=0).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.value_counts("Actor",ascending=False)
# Out:
# Actor
# Roger Moore       7
# Sean Connery      7
# Daniel Craig      4
# Pierce Brosnan    4
# Timothy Dalton    2
# David Niven       1
# George Lazenby    1
# dtype: int64

# %%
bond.nlargest(3, "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, columns = "Budget")

bond.nsmallest(n = 6, columns = "Bond Actor Salary")
# Out:
#                                  Year           Actor         Director  \
# Film
# Dr. No                           1962    Sean Connery    Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# From Russia with Love            1963    Sean Connery    Terence Young
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# You Only Live Twice              1967    Sean Connery    Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Casino Royale                         581.5   145.3                3.3
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond["Box Office"].nlargest(8)

bond["Year"].nsmallest(2)

# %% [markdown]
# ## Filtering with the `where` Method

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# Never Say Never Again            1983.0  Sean Connery  Irvin Kershner
# Octopussy                           NaN           NaN             NaN
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Quantum of Solace                   NaN           NaN             NaN
# Skyfall                             NaN           NaN             NaN
# Spectre                             NaN           NaN             NaN
# The Living Daylights                NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# The World Is Not Enough             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Tomorrow Never Dies                 NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.where(bond["Box Office"] > 800)

# %%
mask2 = bond["Box Office"] > 800

# %%
bond.where(mask & mask2)

# %% [markdown]
# ## The `.query()` Method

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor == "Sean Connery"')
bond.query("Director == 'Terence Young'")
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Never Say Never Again                 380.0    86.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' or Director == 'John Glen'")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# Licence to Kill                56.7                7.9
# Live and Let Die               30.8                NaN
# Moonraker                      91.5                NaN
# Octopussy                      53.9                7.8
# The Living Daylights           68.8                5.2
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN

# %%
bond.query("Actor in ['Timothy Dalton', 'George Lazenby']")

bond.query("Actor not in ['Sean Connery', 'Roger Moore']")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Die Another Day                       465.4   154.2               17.9
# GoldenEye                             518.5    76.9                5.1
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Tomorrow Never Dies                   463.2   133.9               10.0

# %% [markdown]
# ## A Review of the `.apply()` Method on Single Columns

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond["Box Office"]=bond["Box Office"].apply(lambda x:str(x)+" million")

# %%
bond.head(5)
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop("Box Office",axis=1)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Budget  Bond Actor Salary     Box office
# Film
# A View to a Kill                   54.5                9.1  275.2 million
# Casino Royale                     145.3                3.3  581.5 million
# Casino Royale                      85.0                NaN  315.0 million
# Diamonds Are Forever               34.7                5.8  442.5 million
# Die Another Day                   154.2               17.9  465.4 million
# Dr. No                              7.0                0.6  448.8 million
# For Your Eyes Only                 60.2                NaN  449.4 million
# From Russia with Love              12.6                1.6  543.8 million
# GoldenEye                          76.9                5.1  518.5 million
# Goldfinger                         18.6                3.2  820.4 million
# Licence to Kill                    56.7                7.9  250.9 million
# Live and Let Die                   30.8                NaN  460.3 million
# Moonraker                          91.5                NaN  535.0 million
# Never Say Never Again              86.0                NaN  380.0 million
# Octopussy                          53.9                7.8  373.8 million
# On Her Majesty's Secret Service    37.3                0.6  291.5 million
# Quantum of Solace                 181.4                8.1  514.2 million
# Skyfall                           170.2               14.5  943.5 million
# Spectre                           206.3                NaN  726.7 million
# The Living Daylights               68.8                5.2  313.5 million
# The Man with the Golden Gun        27.7                NaN  334.0 million
# The Spy Who Loved Me               45.1                NaN  533.0 million
# The World Is Not Enough           158.3               13.5  439.5 million
# Thunderball                        41.9                4.7  848.1 million
# Tomorrow Never Dies               133.9               10.0  463.2 million
# You Only Live Twice                59.9                4.4  514.2 million

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(lambda x:str(x)+" millions")

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                                              Box Office  \
# Film
# A View to a Kill                 275.2 million million million millions
# Casino Royale                    581.5 million million million millions
# Casino Royale                    315.0 million million million millions
# Diamonds Are Forever             442.5 million million million millions
# Die Another Day                  465.4 million million million millions
# Dr. No                           448.8 million million million millions
# For Your Eyes Only               449.4 million million million millions
# From Russia with Love            543.8 million million million millions
# GoldenEye                        518.5 million million million millions
# Goldfinger                       820.4 million million million millions
# Licence to Kill                  250.9 million million million millions
# Live and Let Die                 460.3 million million million millions
# Moonraker                        535.0 million million million millions
# Never Say Never Again            380.0 million million million millions
# Octopussy                        373.8 million million million millions
# On Her Majesty's Secret Service  291.5 million million million millions
# Quantum of Solace                514.2 million million million millions
# Skyfall                          943.5 million million million millions
# Spectre                          726.7 million million million millions
# The Living Daylights             313.5 million million million millions
# The Man with the Golden Gun      334.0 million million million millions
# The Spy Who Loved Me             533.0 million million million millions
# The World Is Not Enough          439.5 million million million millions
# Thunderball                      848.1 million million million millions
# Tomorrow Never Dies              463.2 million million million millions
# You Only Live Twice              514.2 million million million millions
#
#                                          Budget Bond Actor Salary  \
# Film
# A View to a Kill                  54.5 millions      9.1 millions
# Casino Royale                    145.3 millions      3.3 millions
# Casino Royale                     85.0 millions      nan millions
# Diamonds Are Forever              34.7 millions      5.8 millions
# Die Another Day                  154.2 millions     17.9 millions
# Dr. No                             7.0 millions      0.6 millions
# For Your Eyes Only                60.2 millions      nan millions
# From Russia with Love             12.6 millions      1.6 millions
# GoldenEye                         76.9 millions      5.1 millions
# Goldfinger                        18.6 millions      3.2 millions
# Licence to Kill                   56.7 millions      7.9 millions
# Live and Let Die                  30.8 millions      nan millions
# Moonraker                         91.5 millions      nan millions
# Never Say Never Again             86.0 millions      nan millions
# Octopussy                         53.9 millions      7.8 millions
# On Her Majesty's Secret Service   37.3 millions      0.6 millions
# Quantum of Solace                181.4 millions      8.1 millions
# Skyfall                          170.2 millions     14.5 millions
# Spectre                          206.3 millions      nan millions
# The Living Daylights              68.8 millions      5.2 millions
# The Man with the Golden Gun       27.7 millions      nan millions
# The Spy Who Loved Me              45.1 millions      nan millions
# The World Is Not Enough          158.3 millions     13.5 millions
# Thunderball                       41.9 millions      4.7 millions
# Tomorrow Never Dies              133.9 millions     10.0 millions
# You Only Live Twice               59.9 millions      4.4 millions
#
#                                     Box office
# Film
# A View to a Kill                 275.2 million
# Casino Royale                    581.5 million
# Casino Royale                    315.0 million
# Diamonds Are Forever             442.5 million
# Die Another Day                  465.4 million
# Dr. No                           448.8 million
# For Your Eyes Only               449.4 million
# From Russia with Love            543.8 million
# GoldenEye                        518.5 million
# Goldfinger                       820.4 million
# Licence to Kill                  250.9 million
# Live and Let Die                 460.3 million
# Moonraker                        535.0 million
# Never Say Never Again            380.0 million
# Octopussy                        373.8 million
# On Her Majesty's Secret Service  291.5 million
# Quantum of Solace                514.2 million
# Skyfall                          943.5 million
# Spectre                          726.7 million
# The Living Daylights             313.5 million
# The Man with the Golden Gun      334.0 million
# The Spy Who Loved Me             533.0 million
# The World Is Not Enough          439.5 million
# Thunderball                      848.1 million
# Tomorrow Never Dies              463.2 million
# You Only Live Twice              514.2 million

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director       Box Office  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2 MILLIONS!
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5 MILLIONS!
# Casino Royale     1967   David Niven       Ken Hughes  315.0 MILLIONS!
#
#                            Budget Bond Actor Salary
# Film
# A View to a Kill   54.5 MILLIONS!     9.1 MILLIONS!
# Casino Royale     145.3 MILLIONS!     3.3 MILLIONS!
# Casino Royale      85.0 MILLIONS!     nan MILLIONS!

# %% [markdown]
# ## The `.apply()` Method with Row Values

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Brosnan":
        return "The best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis = "columns")
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# The Living Daylights               I have no clue
# The Man with the Golden Gun        I have no clue
# The Spy Who Loved Me                    Enjoyable
# The World Is Not Enough                  The best
# Thunderball                        I have no clue
# Tomorrow Never Dies                      The best
# You Only Live Twice                I have no clue
# dtype: object

# %%
bond.apply(lambda x:x[0])
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# dtype: object

# %% [markdown]
# ## The `.copy()` Method

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"]
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# <ipython-input-178-55f5cdba50a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"].copy()
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
